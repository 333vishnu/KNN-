# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
sns.set()

# %%
df = pd.read_csv("Zoo.csv")

# %%
zoo = df.copy()

# %%
zoo.head()
# Out:
#   animal name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0    aardvark     1         0     0     1         0        0         1
# 1    antelope     1         0     0     1         0        0         0
# 2        bass     0         0     1     0         0        1         1
# 3        bear     1         0     0     1         0        0         1
# 4        boar     1         0     0     1         0        0         1
#
#    toothed  backbone  breathes  venomous  fins  legs  tail  domestic  catsize  \
# 0        1         1         1         0     0     4     0         0        1
# 1        1         1         1         0     0     4     1         0        1
# 2        1         1         0         0     1     0     1         0        0
# 3        1         1         1         0     0     4     0         0        1
# 4        1         1         1         0     0     4     1         0        1
#
#    type
# 0     1
# 1     1
# 2     4
# 3     1
# 4     1

# %%
zoo.describe()
# Out:
#              hair    feathers        eggs        milk    airborne     aquatic  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.425743    0.198020    0.584158    0.405941    0.237624    0.356436
# std      0.496921    0.400495    0.495325    0.493522    0.427750    0.481335
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 75%      1.000000    0.000000    1.000000    1.000000    0.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          predator     toothed    backbone    breathes    venomous        fins  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.554455    0.603960    0.821782    0.792079    0.079208    0.168317
# std      0.499505    0.491512    0.384605    0.407844    0.271410    0.376013
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000    1.000000    0.000000    0.000000
# 50%      1.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#              legs        tail    domestic     catsize        type
# count  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     2.841584    0.742574    0.128713    0.435644    2.831683
# std      2.033385    0.439397    0.336552    0.498314    2.102709
# min      0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      2.000000    0.000000    0.000000    0.000000    1.000000
# 50%      4.000000    1.000000    0.000000    0.000000    2.000000
# 75%      4.000000    1.000000    0.000000    1.000000    4.000000
# max      8.000000    1.000000    1.000000    1.000000    7.000000

# %%
sns.factorplot('type', data=zoo, kind="count",size = 5,aspect = 2) 
import warnings 
warnings.filterwarnings("ignore")

# %%
zoo.plot(kind='box', subplots=True, layout=(4,5), figsize=(12,21), sharex=False, sharey=False)
plt.show()

# %%
## correlation between variabels
cor = zoo.corr(method='pearson')

# %%
cor.style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_32f97_row0_col0, #T_32f97_row1_col1, #T_32f97_row2_col2, #T_32f97_row3_col3, #T_32f97_row4_col4, #T_32f97_row5_col5, #T_32f97_row6_col6, #T_32f97_row7_col7, #T_32f97_row8_col8, #T_32f97_row9_col9, #T_32f97_row10_col10, #T_32f97_row11_col11, #T_32f97_row12_col12, #T_32f97_row13_col13, #T_32f97_row14_col14, #T_32f97_row15_col15, #T_32f97_row16_col16 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_32f97_row0_col1, #T_32f97_row0_col10 {
#   background-color: #482979;
#   color: #f1f1f1;
# }
# #T_32f97_row0_col2, #T_32f97_row5_col14 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_32f97_row0_col3 {
#   background-color: #d5e21a;
#   color: #000000;
# }
# #T_32f97_row0_col4, #T_32f97_row1_col12 {
#   background-color: #3b518b;
#   color: #f1f1f1;
# }
# #T_32f97_row0_col5, #T_32f97_row9_col10, #T_32f97_row16_col14 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_32f97_row0_col6, #T_32f97_row2_col14 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_32f97_row0_col7 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_32f97_row0_col8, #T_32f97_row8_col0 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_32f97_row0_col9 {
#   background-color: #32b67a;
#   color: #f1f1f1;
# }
# #T_32f97_row0_col11 {
#   background-color: #404688;
#   color: #f1f1f1;
# }
# #T_32f97_row0_col12 {
#   background-color: #27ad81;
#   color: #f1f1f1;
# }
# #T_32f97_row0_col13 {
#   background-color: #287c8e;
#   color: #f1f1f1;
# }
# #T_32f97_row0_col14, #T_32f97_row4_col8 {
#   background-color: #2a778e;
#   color: #f1f1f1;
# }
# #T_32f97_row0_col15 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_32f97_row0_col16, #T_32f97_row7_col10 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_32f97_row1_col0, #T_32f97_row3_col6 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_32f97_row1_
{
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_32f97_row4_col0 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_32f97_row4_col1 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_32f97_row4_col2, #T_32f97_row5_col2 {
#   background-color: #3aba76;
#   color: #f1f1f1;
# }
# #T_32f97_row4_col3, #T_32f97_row11_col0, #T_32f97_row15_col1 {
#   background-color: #355e8d;
#   color: #f1f1f1;
# }
# #T_32f97_row4_col6 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_32f97_row4_col7 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_32f97_row4_col9, #T_32f97_row14_col0 {
#   background-color: #1fa088;
#   color: #f1f1f1;
# }
# #T_32f97_row4_col10 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_32f97_row4_col11 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
# }
# #T_32f97_row4_col12, #T_32f97_row8_col5, #T_32f97_row11_col3, #T_32f97_row14_col2 {
#   background-color: #29798e;
#   color: #f1f1f1;
# }
# #T_32f97_row4_col13, #T_32f97_row10_col0, #T_32f97_row10_col12 {
#   background-color: #2a768e;
#   color: #f1f1f1;
# }
# #T_32f97_row4_col15, #T_32f97_row16_col3 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_32f97_row4_col16, #T_32f97_row5_col8, #T_32f97_row14_col9 {
#   background-color: #23888e;
#   color: #f1f1f1;
# }
# #T_32f97_row5_col0, #T_32f97_row6_col4 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# #T_32f97_row5_col3 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_32f97_row5_col4 {
#   background-color: #39558c;
#   color: #f1f1f1;
# }
# #T_32f97_row5_col6, #T_32f97_row8_col1, #T_32f97_row12_col16 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_32f97_row5_col7, #T_32f97_row14_col12 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# #T_32f97_row5_col11 {
#   background-color: #60ca60;
#   color: #000000;
# }
# #T_32f97_row5_col13, #T_32f97_row6_col0, #T_32f97_row11_col15 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_32f97_row5_col16, #T_32f97_row10_col16 {
#   background-color: #29af7f;
#   color: #f1f1f1;
# }
# #T_32f97_row6_col1, #T_32f97_row6_col12, #T_32f97_row8_col14, #T_32f97_row10_col9 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_32f97_row6_col2 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_32f97_row6_col3, #T_32f97_row6_col7 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_32f97_row6_col9 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_32f97_row6_col10, #T_32f97_row7_col14, #T_32f97_row10_col1, #T_32f

# %%
## using KNN
X = zoo.iloc[:,1:17] 
y = zoo.iloc[:,17]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %%
k_values = np.arange(1,25)
train_accuracy = []
test_accuracy = []

# %%
for i, k in enumerate(k_values):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,y_train)
    train_accuracy.append(knn.score(X_train, y_train))
    test_accuracy.append(knn.score(X_test, y_test))

# %%
plt.figure(figsize=[12,9])
plt.plot(k_values, test_accuracy, label = 'Testing Accuracy')
plt.plot(k_values, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(k_values)
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train, y_train)
y_pred_KNeighborsClassifier = knn.predict(X_test)

# %%
scores = []
cv_scores = []

# %%
score = accuracy_score(y_pred_KNeighborsClassifier,y_test)
scores.append(score)

# %%
score_knn=cross_val_score(knn, X,y, cv=10)

# %%
score_knn.mean()
# Out:
# 0.8809090909090909

# %%
score_knn.std()*2
# Out:
# 0.12072782037115655

# %%
cv_score = score_knn.mean()

# %%
cv_scores.append(cv_score)

# %%
cv_scores
# Out:
# [0.8809090909090909]

# %%
print("Accuracy of the model is 89% approx")
# Out:
# Accuracy of the model is 89% approx
